# %%
import pandas as pd
import json

# %%
df = pd.read_csv("lakes.csv")

# %%
d
# Out:
#          id_int        id_str             Name  countries(iso)  \
# 0             1  GLWD00000001      Caspian Sea  IR;RU;KZ;TM;AZ
# 1             2  GLWD00000002         Superior           US;CA
# 2             3  GLWD00000003         Victoria        TZ;UG;KE
# 3             4  GLWD00000004   Large Aral Sea           UZ;KZ
# 4             5  GLWD00000005            Huron           CA;US
# ...         ...           ...              ...             ...
# 4259  300013182  HYLA00013182   Östra Ringsjön              SE
# 4260      10679  GLWD00010679  ALBUFERA-Lagoon              ES
# 4261  300134644  HYLA00134644       Rihpojávri              NO
# 4262  301382089  HYLA01382089             Imja              NP
# 4263  200000072  CGL200000072        Maracaibo              VE
#
#                                               countries continents(iso)  \
# 0     Iran Islamic Republic of;Russian Federation;Ka...        AS;EU;AS
# ...

# %%
out = []
for index, row in df.iterrows():
    print(row)
# Out:
# id_int                                                             1
# id_str                                                  GLWD00000001
# Name                                                     Caspian Sea
# countries(iso)                                        IR;RU;KZ;TM;AZ
# countries          Iran Islamic Republic of;Russian Federation;Ka...
# continents(iso)                                             AS;EU;AS
# continents                                          Asia;Europe;Asia
# area(km2)                                                     379446
# repr_point_lat                                             41.845142
# repr_point_lon                                               50.5333
# repr_point_wkt                   POINT (50.5333185792 41.8451419708)
# Name: 0, dtype: object
# id_int                                                    2
# id_str                                         GLWD00000002
# Name                                               Superior
# ...
